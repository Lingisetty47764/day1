# %%
# Out:
# Running cells with 'my_sample (3.13.1.final.0) (Python 3.13.1)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/lingi/OneDrive/Attachments/OneDrive/Desktop/Git_pratice/my_sample/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'

# %%
2+1

# %%
list = [2,4,6,20,19]
even = []
for i in list:
    if i%2==0:
        even.append(i)
print(even)
